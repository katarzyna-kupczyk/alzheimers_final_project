# %% [markdown]
# # Introduction + Set-up
#
# Machine learning has a phenomenal range of application in the health sciences. This tutorial will go over the complete pipeline to build a model that can determine the dementia level of an Alzheimer's patient from their MRI image. This model achieves an a high ROC AUC score.
#
# This tutorial highlights the ease of building a CNN using `tf.keras`. Additionally, TensorFlow 2.3 has new features, including easy data loading utilities that were previously not available in TensorFlow 2.2. We'll be seeing how easy data loading is with these additional features.
#
# We'll be using a GPU accelerator for this NB.

# %%
# !pip install tensorflow==2.3.0 -q

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
# from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
import PIL

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.6.0

# %% [markdown]
# It's always a good idea to set constant variables instead of hard coding numbers into your code. It saves time later when you want to change certain parameters.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [176, 208]
EPOCHS = 100

# %% [markdown]
# # Data Loading
#
# We'll be using a [Kaggle Alzheimer's dataset](https://www.kaggle.com/tourist55/alzheimers-dataset-4-class-of-images) for our tutorial. `tf.keras` has a new preprocessing function that can easily load in images for a directory. In order for this function to work, the data has to be structured in a file directory format.
#
# ```
# main_directory/
#     class1/
#         class1_images
#     class2/
#         class2_images
# ```
#
# If you input the `main_directory` into the `tf.keras` function, it will figure out the rest!
# In our case, the `train` directory is our main directory.
#
# We are also specifying a 80:20 split for our training and validation datasets. To learn more about the importance of having a validation split, check out this [lesson](https://developers.google.com/machine-learning/crash-course/validation/another-partition) from Google's Machine Learning Crash Course.

# %%
# Connecting to google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/LeWagon/raw_data/AlzheimersDataset/train",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/LeWagon/raw_data/AlzheimersDataset/train",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.

# %% [markdown]
# We'll be renaming the class names and specifying the number of classes. In this case, we have 4 classes of dementia.

# %%
class_names = ['MildDementia', 'ModerateDementia', 'NonDementia', 'VeryMildDementia']
train_ds.class_names = class_names
val_ds.class_names = class_names

NUM_CLASSES = len(class_names)

# %% [markdown]
# # Visualize the data
#
# Now that our data has been easily loaded in, the next step is to visualize our images. This helps us understand what is being used as an input for our model. It also serves as a check to see if our images have been loaded in correctly.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(train_ds.class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# # Feature Engineering
#
# Because we are working with categorical and noncontinuous data, we want to convert our model into one-hot encodings. One-hot encodings are a way for the model to understand that we're looking at categorial instead of continuous data. Transforming features so that they'll be more understandable is called feature engineering. Learn more about feature engineering [here](https://developers.google.com/machine-learning/crash-course/representation/feature-engineering).

# %%
def one_hot_label(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label

train_ds = train_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# The following cell makes calling images from our dataset more efficient.

# %%
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Deciding a Metric
#
# The most conventional metric to use is probably accuracy. Accuracy, however, cannot be used for imbalanced datasets. Let's check how many images are in each class for our training data.

# %%
NUM_IMAGES = []

for label in class_names:
    dir_name = "../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/" + label[:-2] + 'ed'
    NUM_IMAGES.append(len([name for name in os.listdir(dir_name)]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-5592bc0f5c11> in <module>()
#       3 for label in class_names:
#       4     dir_name = "../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/" + label[:-2] + 'ed'
# ----> 5     NUM_IMAGES.append(len([name for name in os.listdir(dir_name)]))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train/MildDemented'

# %%
NUM_IMAGES

# %% [markdown]
# Our dataset is not balanced, so we cannot use accuracy as our metric. For this tutorial, we will be using ROC AUC. Intuitively, ROC AUC gives a score, with higher scores closer to 1 indicating that the different classes can be distinguishable for the model. A lower score closer indicates that the the model cannot distinguish between different classes. A score of 0.5 indicates that the ordering the images is pretty much random. Learn more about ROC AUC [here](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc).

# %% [markdown]
# # Build the ML Model
#
# We'll be using the same architecture for our model as my [Pneumonia Classification NB](https://www.kaggle.com/amyjang/tensorflow-pneumonia-classification-on-x-rays#4.-Build-the-CNN). Using `tf.keras`, we can easily build up the layers of our CNN.

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(*IMAGE_SIZE, 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

# %%
with strategy.scope():
    model = build_model()

    METRICS = [tf.keras.metrics.AUC(name='auc'), 'accuracy', 'Recall', 'Precision']
    
    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )

# %% [markdown]
# # Training the Model
#
# To more efficiently train our model. We will be using callbacks to adjust our learning rate and to stop our model once it converges.
#
# The [learning rate](https://developers.google.com/machine-learning/glossary#learning-rate) is a very important hyperparameter in the model. Having a LR that is too high will prevent the model from converging. Having a LR that is too slow will make the process too long. Stopping our model early is one mechanism that prevents overfitting.

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=30,
                                                     restore_best_weights=True)

# %% [markdown]
# Let's fit our model!

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
    epochs=EPOCHS
)
# Out:
# Epoch 1/100
# 257/257 [==============================] - 704s 3s/step - loss: 1.0930 - auc: 0.7864 - accuracy: 0.4972 - recall: 0.3354 - precision: 0.5715 - val_loss: 7.0341 - val_auc: 0.6597 - val_accuracy: 0.4951 - val_recall: 0.4951 - val_precision: 0.4951
# Epoch 2/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.9793 - auc: 0.8124 - accuracy: 0.5138 - recall: 0.3139 - precision: 0.6264 - val_loss: 1.0538 - val_auc: 0.7708 - val_accuracy: 0.4111 - val_recall: 0.0342 - val_precision: 0.8750
# Epoch 3/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.9770 - auc: 0.8117 - accuracy: 0.5121 - recall: 0.2758 - precision: 0.6395 - val_loss: 1.9753 - val_auc: 0.7733 - val_accuracy: 0.4844 - val_recall: 0.4814 - val_precision: 0.4867
# Epoch 4/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.9581 - auc: 0.8223 - accuracy: 0.5333 - recall: 0.2988 - precision: 0.6659 - val_loss: 15.6507 - val_auc: 0.6632 - val_accuracy: 0.4951 - val_recall: 0.4951 - val_precision: 0.4951
# Epoch 5/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.9502 - auc: 0.8253 - accuracy: 0.5472 - recall: 0.3212 - precision: 0.6587 - val_loss: 1.1007 - val_auc: 0.7515 - val_accuracy: 0.5293 - val_recall: 0.0029 - val_precision: 1.0000
# Epoch 6/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.9259 - auc: 0.8346 - accuracy: 0.5668 - recall: 0.3556 - precision: 0.6758 - val_loss: 1.0107 - val_auc: 0.7985 - val_accuracy: 0.4893 - val_recall: 0.1982 - val_precision: 0.6285
# Epoch 7/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.9166 - auc: 0.8397 - accuracy: 0.5758 - recall: 0.3773 - precision: 0.6733 - val_loss: 1.0093 - val_auc: 0.8105 - val_accuracy: 0.5352 - val_recall: 0.1504 - val_precision: 0.8105
# Epoch 8/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.9043 - auc: 0.8431 - accuracy: 0.5736 - recall: 0.3935 - precision: 0.6785 - val_loss: 1.5915 - val_auc: 0.8062 - val_accuracy: 0.4961 - val_recall: 0.4775 - val_precision: 0.5197
# Epoch 9/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8928 - auc: 0.8468 - accuracy: 0.5794 - recall: 0.4149 - precision: 0.6816 - val_loss: 4.3917 - val_auc: 0.6938 - val_accuracy: 0.5010 - val_recall: 0.4990 - val_precision: 0.5015
# Epoch 10/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8899 - auc: 0.8485 - accuracy: 0.5760 - recall: 0.4123 - precision: 0.6855 - val_loss: 1.4966 - val_auc: 0.8088 - val_accuracy: 0.5088 - val_recall: 0.4561 - val_precision: 0.5230
# Epoch 11/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8766 - auc: 0.8535 - accuracy: 0.5831 - recall: 0.4142 - precision: 0.6834 - val_loss: 1.1441 - val_auc: 0.8262 - val_accuracy: 0.5254 - val_recall: 0.4375 - val_precision: 0.5417
# Epoch 12/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.8667 - auc: 0.8570 - accuracy: 0.5899 - recall: 0.4420 - precision: 0.6891 - val_loss: 5.5192 - val_auc: 0.6810 - val_accuracy: 0.4971 - val_recall: 0.4961 - val_precision: 0.4966
# Epoch 13/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8642 - auc: 0.8583 - accuracy: 0.5931 - recall: 0.4452 - precision: 0.6904 - val_loss: 1.8802 - val_auc: 0.7935 - val_accuracy: 0.5078 - val_recall: 0.5000 - val_precision: 0.5156
# Epoch 14/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8574 - auc: 0.8596 - accuracy: 0.5948 - recall: 0.4496 - precision: 0.6840 - val_loss: 1.9646 - val_auc: 0.8019 - val_accuracy: 0.4961 - val_recall: 0.4922 - val_precision: 0.5045
# Epoch 15/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.9012 - auc: 0.8420 - accuracy: 0.5629 - recall: 0.3705 - precision: 0.6903 - val_loss: 0.9141 - val_auc: 0.8372 - val_accuracy: 0.5410 - val_recall: 0.5156 - val_precision: 0.5641
# Epoch 16/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8787 - auc: 0.8544 - accuracy: 0.5875 - recall: 0.4132 - precision: 0.7048 - val_loss: 1.0839 - val_auc: 0.8320 - val_accuracy: 0.5176 - val_recall: 0.4658 - val_precision: 0.5592
# Epoch 17/100
# 257/257 [==============================] - 16s 63ms/step - loss: 0.8554 - auc: 0.8624 - accuracy: 0.6039 - recall: 0.4577 - precision: 0.7012 - val_loss: 0.8530 - val_auc: 0.8650 - val_accuracy: 0.6055 - val_recall: 0.4102 - val_precision: 0.7095
# Epoch 18/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8520 - auc: 0.8624 - accuracy: 0.5958 - recall: 0.4472 - precision: 0.6968 - val_loss: 1.0898 - val_auc: 0.8348 - val_accuracy: 0.5420 - val_recall: 0.4990 - val_precision: 0.5767
# Epoch 19/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8388 - auc: 0.8677 - accuracy: 0.6070 - recall: 0.4767 - precision: 0.7058 - val_loss: 0.8234 - val_auc: 0.8700 - val_accuracy: 0.6074 - val_recall: 0.4531 - val_precision: 0.7160
# Epoch 20/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8264 - auc: 0.8717 - accuracy: 0.6187 - recall: 0.4835 - precision: 0.7052 - val_loss: 0.8734 - val_auc: 0.8628 - val_accuracy: 0.5957 - val_recall: 0.5156 - val_precision: 0.6625
# Epoch 21/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.8219 - auc: 0.8729 - accuracy: 0.6124 - recall: 0.4779 - precision: 0.7010 - val_loss: 0.9518 - val_auc: 0.8501 - val_accuracy: 0.5625 - val_recall: 0.4902 - val_precision: 0.6085
# Epoch 22/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8213 - auc: 0.8731 - accuracy: 0.6097 - recall: 0.4867 - precision: 0.7142 - val_loss: 0.8304 - val_auc: 0.8636 - val_accuracy: 0.5771 - val_recall: 0.4521 - val_precision: 0.6994
# Epoch 23/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.8053 - auc: 0.8782 - accuracy: 0.6229 - recall: 0.4891 - precision: 0.7066 - val_loss: 0.8253 - val_auc: 0.8729 - val_accuracy: 0.5986 - val_recall: 0.5371 - val_precision: 0.6478
# Epoch 24/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7940 - auc: 0.8822 - accuracy: 0.6385 - recall: 0.5113 - precision: 0.7212 - val_loss: 0.7778 - val_auc: 0.8847 - val_accuracy: 0.6338 - val_recall: 0.5195 - val_precision: 0.7278
# Epoch 25/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.7899 - auc: 0.8840 - accuracy: 0.6290 - recall: 0.5165 - precision: 0.7144 - val_loss: 0.8125 - val_auc: 0.8772 - val_accuracy: 0.6172 - val_recall: 0.4902 - val_precision: 0.7100
# Epoch 26/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7763 - auc: 0.8893 - accuracy: 0.6466 - recall: 0.5399 - precision: 0.7325 - val_loss: 0.7767 - val_auc: 0.8880 - val_accuracy: 0.6318 - val_recall: 0.5400 - val_precision: 0.7201
# Epoch 27/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7639 - auc: 0.8921 - accuracy: 0.6534 - recall: 0.5448 - precision: 0.7270 - val_loss: 0.7614 - val_auc: 0.8914 - val_accuracy: 0.6475 - val_recall: 0.5117 - val_precision: 0.7486
# Epoch 28/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7548 - auc: 0.8952 - accuracy: 0.6644 - recall: 0.5580 - precision: 0.7346 - val_loss: 0.7838 - val_auc: 0.8850 - val_accuracy: 0.6162 - val_recall: 0.5508 - val_precision: 0.6698
# Epoch 29/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7411 - auc: 0.8994 - accuracy: 0.6715 - recall: 0.5687 - precision: 0.7402 - val_loss: 0.7603 - val_auc: 0.8926 - val_accuracy: 0.6562 - val_recall: 0.5596 - val_precision: 0.7281
# Epoch 30/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7307 - auc: 0.9019 - accuracy: 0.6695 - recall: 0.5829 - precision: 0.7398 - val_loss: 0.7337 - val_auc: 0.8989 - val_accuracy: 0.6602 - val_recall: 0.5859 - val_precision: 0.7160
# Epoch 31/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.7198 - auc: 0.9060 - accuracy: 0.6829 - recall: 0.5941 - precision: 0.7448 - val_loss: 0.7005 - val_auc: 0.9099 - val_accuracy: 0.6973 - val_recall: 0.6016 - val_precision: 0.7739
# Epoch 32/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.7126 - auc: 0.9089 - accuracy: 0.6944 - recall: 0.6117 - precision: 0.7550 - val_loss: 0.6792 - val_auc: 0.9161 - val_accuracy: 0.6943 - val_recall: 0.5898 - val_precision: 0.7694
# Epoch 33/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.6897 - auc: 0.9146 - accuracy: 0.6978 - recall: 0.6205 - precision: 0.7514 - val_loss: 0.7442 - val_auc: 0.9052 - val_accuracy: 0.6895 - val_recall: 0.5742 - val_precision: 0.7510
# Epoch 34/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.6792 - auc: 0.9176 - accuracy: 0.7132 - recall: 0.6371 - precision: 0.7596 - val_loss: 0.7523 - val_auc: 0.9099 - val_accuracy: 0.6914 - val_recall: 0.5859 - val_precision: 0.7595
# Epoch 35/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.6591 - auc: 0.9220 - accuracy: 0.7171 - recall: 0.6412 - precision: 0.7641 - val_loss: 0.6516 - val_auc: 0.9269 - val_accuracy: 0.7246 - val_recall: 0.6484 - val_precision: 0.7858
# Epoch 36/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.6478 - auc: 0.9250 - accuracy: 0.7239 - recall: 0.6544 - precision: 0.7675 - val_loss: 1.2119 - val_auc: 0.8864 - val_accuracy: 0.6523 - val_recall: 0.5742 - val_precision: 0.7076
# Epoch 37/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.6551 - auc: 0.9229 - accuracy: 0.7191 - recall: 0.6519 - precision: 0.7653 - val_loss: 0.6699 - val_auc: 0.9233 - val_accuracy: 0.7168 - val_recall: 0.6445 - val_precision: 0.7811
# Epoch 38/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.6319 - auc: 0.9286 - accuracy: 0.7291 - recall: 0.6644 - precision: 0.7720 - val_loss: 0.6250 - val_auc: 0.9306 - val_accuracy: 0.7354 - val_recall: 0.6621 - val_precision: 0.7884
# Epoch 39/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.6213 - auc: 0.9309 - accuracy: 0.7391 - recall: 0.6846 - precision: 0.7846 - val_loss: 0.6338 - val_auc: 0.9327 - val_accuracy: 0.7393 - val_recall: 0.6641 - val_precision: 0.7870
# Epoch 40/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.6214 - auc: 0.9306 - accuracy: 0.7340 - recall: 0.6763 - precision: 0.7764 - val_loss: 0.6591 - val_auc: 0.9284 - val_accuracy: 0.7217 - val_recall: 0.6748 - val_precision: 0.7695
# Epoch 41/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.6049 - auc: 0.9346 - accuracy: 0.7488 - recall: 0.6881 - precision: 0.7857 - val_loss: 0.6440 - val_auc: 0.9323 - val_accuracy: 0.7363 - val_recall: 0.6729 - val_precision: 0.7920
# Epoch 42/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5973 - auc: 0.9362 - accuracy: 0.7498 - recall: 0.7005 - precision: 0.7874 - val_loss: 0.6250 - val_auc: 0.9363 - val_accuracy: 0.7480 - val_recall: 0.6924 - val_precision: 0.7948
# Epoch 43/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5941 - auc: 0.9369 - accuracy: 0.7491 - recall: 0.7020 - precision: 0.7884 - val_loss: 0.6064 - val_auc: 0.9365 - val_accuracy: 0.7520 - val_recall: 0.6934 - val_precision: 0.8023
# Epoch 44/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5852 - auc: 0.9387 - accuracy: 0.7481 - recall: 0.7073 - precision: 0.7884 - val_loss: 0.6249 - val_auc: 0.9387 - val_accuracy: 0.7529 - val_recall: 0.7070 - val_precision: 0.8080
# Epoch 45/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5893 - auc: 0.9380 - accuracy: 0.7581 - recall: 0.7091 - precision: 0.7961 - val_loss: 0.6196 - val_auc: 0.9376 - val_accuracy: 0.7539 - val_recall: 0.7002 - val_precision: 0.8083
# Epoch 46/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5789 - auc: 0.9401 - accuracy: 0.7520 - recall: 0.7039 - precision: 0.7884 - val_loss: 0.6108 - val_auc: 0.9385 - val_accuracy: 0.7588 - val_recall: 0.7041 - val_precision: 0.8002
# Epoch 47/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5786 - auc: 0.9405 - accuracy: 0.7674 - recall: 0.7213 - precision: 0.8032 - val_loss: 0.6160 - val_auc: 0.9386 - val_accuracy: 0.7539 - val_recall: 0.6992 - val_precision: 0.7956
# Epoch 48/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5771 - auc: 0.9407 - accuracy: 0.7610 - recall: 0.7178 - precision: 0.7983 - val_loss: 0.6932 - val_auc: 0.9235 - val_accuracy: 0.7148 - val_recall: 0.6807 - val_precision: 0.7609
# Epoch 49/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5769 - auc: 0.9405 - accuracy: 0.7576 - recall: 0.7137 - precision: 0.7909 - val_loss: 0.5821 - val_auc: 0.9404 - val_accuracy: 0.7637 - val_recall: 0.7109 - val_precision: 0.8044
# Epoch 50/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5782 - auc: 0.9405 - accuracy: 0.7557 - recall: 0.7142 - precision: 0.7889 - val_loss: 0.5964 - val_auc: 0.9412 - val_accuracy: 0.7637 - val_recall: 0.7119 - val_precision: 0.8020
# Epoch 51/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.5744 - auc: 0.9411 - accuracy: 0.7664 - recall: 0.7232 - precision: 0.7982 - val_loss: 0.5990 - val_auc: 0.9416 - val_accuracy: 0.7627 - val_recall: 0.7090 - val_precision: 0.8013
# Epoch 52/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.5642 - auc: 0.9434 - accuracy: 0.7669 - recall: 0.7203 - precision: 0.8028 - val_loss: 0.6119 - val_auc: 0.9414 - val_accuracy: 0.7598 - val_recall: 0.7080 - val_precision: 0.8092
# Epoch 53/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5589 - auc: 0.9448 - accuracy: 0.7691 - recall: 0.7261 - precision: 0.8051 - val_loss: 0.5987 - val_auc: 0.9415 - val_accuracy: 0.7627 - val_recall: 0.7100 - val_precision: 0.8033
# Epoch 54/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.5735 - auc: 0.9412 - accuracy: 0.7603 - recall: 0.7169 - precision: 0.7972 - val_loss: 0.6282 - val_auc: 0.9417 - val_accuracy: 0.7617 - val_recall: 0.7158 - val_precision: 0.8046
# Epoch 55/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5664 - auc: 0.9427 - accuracy: 0.7596 - recall: 0.7169 - precision: 0.7968 - val_loss: 0.5970 - val_auc: 0.9419 - val_accuracy: 0.7627 - val_recall: 0.7158 - val_precision: 0.8073
# Epoch 56/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5581 - auc: 0.9446 - accuracy: 0.7681 - recall: 0.7237 - precision: 0.8011 - val_loss: 0.6099 - val_auc: 0.9417 - val_accuracy: 0.7627 - val_recall: 0.7119 - val_precision: 0.8064
# Epoch 57/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5627 - auc: 0.9435 - accuracy: 0.7671 - recall: 0.7259 - precision: 0.8023 - val_loss: 0.6142 - val_auc: 0.9414 - val_accuracy: 0.7598 - val_recall: 0.7139 - val_precision: 0.8024
# Epoch 58/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5596 - auc: 0.9441 - accuracy: 0.7691 - recall: 0.7252 - precision: 0.7995 - val_loss: 0.6266 - val_auc: 0.9421 - val_accuracy: 0.7627 - val_recall: 0.7129 - val_precision: 0.8031
# Epoch 59/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5588 - auc: 0.9443 - accuracy: 0.7698 - recall: 0.7239 - precision: 0.8021 - val_loss: 0.6060 - val_auc: 0.9420 - val_accuracy: 0.7656 - val_recall: 0.7090 - val_precision: 0.8031
# Epoch 60/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5561 - auc: 0.9450 - accuracy: 0.7745 - recall: 0.7313 - precision: 0.8047 - val_loss: 0.6114 - val_auc: 0.9421 - val_accuracy: 0.7646 - val_recall: 0.7129 - val_precision: 0.8022
# Epoch 61/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5467 - auc: 0.9465 - accuracy: 0.7764 - recall: 0.7327 - precision: 0.8089 - val_loss: 0.6047 - val_auc: 0.9420 - val_accuracy: 0.7666 - val_recall: 0.7158 - val_precision: 0.8046
# Epoch 62/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5476 - auc: 0.9469 - accuracy: 0.7815 - recall: 0.7349 - precision: 0.8118 - val_loss: 0.5980 - val_auc: 0.9424 - val_accuracy: 0.7646 - val_recall: 0.7168 - val_precision: 0.8066
# Epoch 63/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5410 - auc: 0.9482 - accuracy: 0.7769 - recall: 0.7310 - precision: 0.8130 - val_loss: 0.5953 - val_auc: 0.9425 - val_accuracy: 0.7637 - val_recall: 0.7148 - val_precision: 0.8044
# Epoch 64/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5569 - auc: 0.9446 - accuracy: 0.7696 - recall: 0.7193 - precision: 0.8065 - val_loss: 0.6014 - val_auc: 0.9422 - val_accuracy: 0.7666 - val_recall: 0.7178 - val_precision: 0.8024
# Epoch 65/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5585 - auc: 0.9441 - accuracy: 0.7581 - recall: 0.7154 - precision: 0.7967 - val_loss: 0.6360 - val_auc: 0.9425 - val_accuracy: 0.7676 - val_recall: 0.7168 - val_precision: 0.8048
# Epoch 66/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5496 - auc: 0.9461 - accuracy: 0.7706 - recall: 0.7300 - precision: 0.8049 - val_loss: 0.6084 - val_auc: 0.9429 - val_accuracy: 0.7646 - val_recall: 0.7158 - val_precision: 0.8046
# Epoch 67/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5521 - auc: 0.9456 - accuracy: 0.7706 - recall: 0.7286 - precision: 0.8078 - val_loss: 0.6147 - val_auc: 0.9430 - val_accuracy: 0.7656 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 68/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5513 - auc: 0.9458 - accuracy: 0.7720 - recall: 0.7349 - precision: 0.8040 - val_loss: 0.6422 - val_auc: 0.9421 - val_accuracy: 0.7656 - val_recall: 0.7168 - val_precision: 0.8022
# Epoch 69/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5592 - auc: 0.9444 - accuracy: 0.7732 - recall: 0.7291 - precision: 0.8082 - val_loss: 0.6021 - val_auc: 0.9423 - val_accuracy: 0.7627 - val_recall: 0.7129 - val_precision: 0.8057
# Epoch 70/100
# 257/257 [==============================] - 16s 64ms/step - loss: 0.5531 - auc: 0.9456 - accuracy: 0.7752 - recall: 0.7322 - precision: 0.8047 - val_loss: 0.6210 - val_auc: 0.9424 - val_accuracy: 0.7646 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 71/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5595 - auc: 0.9443 - accuracy: 0.7679 - recall: 0.7227 - precision: 0.8005 - val_loss: 0.6378 - val_auc: 0.9423 - val_accuracy: 0.7617 - val_recall: 0.7158 - val_precision: 0.8037
# Epoch 72/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.5570 - auc: 0.9449 - accuracy: 0.7730 - recall: 0.7315 - precision: 0.8041 - val_loss: 0.6225 - val_auc: 0.9430 - val_accuracy: 0.7637 - val_recall: 0.7178 - val_precision: 0.8042
# Epoch 73/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5483 - auc: 0.9465 - accuracy: 0.7752 - recall: 0.7310 - precision: 0.8134 - val_loss: 0.6116 - val_auc: 0.9430 - val_accuracy: 0.7676 - val_recall: 0.7178 - val_precision: 0.8059
# Epoch 74/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5508 - auc: 0.9457 - accuracy: 0.7720 - recall: 0.7203 - precision: 0.8012 - val_loss: 0.6376 - val_auc: 0.9426 - val_accuracy: 0.7656 - val_recall: 0.7188 - val_precision: 0.8053
# Epoch 75/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5481 - auc: 0.9465 - accuracy: 0.7779 - recall: 0.7335 - precision: 0.8124 - val_loss: 0.6482 - val_auc: 0.9429 - val_accuracy: 0.7637 - val_recall: 0.7168 - val_precision: 0.8057
# Epoch 76/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5508 - auc: 0.9460 - accuracy: 0.7718 - recall: 0.7310 - precision: 0.8058 - val_loss: 0.6135 - val_auc: 0.9430 - val_accuracy: 0.7627 - val_recall: 0.7188 - val_precision: 0.8053
# Epoch 77/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5468 - auc: 0.9468 - accuracy: 0.7798 - recall: 0.7388 - precision: 0.8177 - val_loss: 0.5782 - val_auc: 0.9427 - val_accuracy: 0.7617 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 78/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5654 - auc: 0.9428 - accuracy: 0.7637 - recall: 0.7235 - precision: 0.7957 - val_loss: 0.5862 - val_auc: 0.9427 - val_accuracy: 0.7676 - val_recall: 0.7168 - val_precision: 0.8004
# Epoch 79/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5487 - auc: 0.9465 - accuracy: 0.7730 - recall: 0.7315 - precision: 0.8046 - val_loss: 0.6168 - val_auc: 0.9425 - val_accuracy: 0.7646 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 80/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5501 - auc: 0.9459 - accuracy: 0.7723 - recall: 0.7318 - precision: 0.8050 - val_loss: 0.6248 - val_auc: 0.9422 - val_accuracy: 0.7646 - val_recall: 0.7139 - val_precision: 0.8024
# Epoch 81/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5523 - auc: 0.9455 - accuracy: 0.7654 - recall: 0.7269 - precision: 0.8018 - val_loss: 0.6308 - val_auc: 0.9425 - val_accuracy: 0.7666 - val_recall: 0.7158 - val_precision: 0.8037
# Epoch 82/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5457 - auc: 0.9470 - accuracy: 0.7776 - recall: 0.7313 - precision: 0.8099 - val_loss: 0.6290 - val_auc: 0.9428 - val_accuracy: 0.7646 - val_recall: 0.7178 - val_precision: 0.8033
# Epoch 83/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5506 - auc: 0.9457 - accuracy: 0.7657 - recall: 0.7257 - precision: 0.8033 - val_loss: 0.6475 - val_auc: 0.9426 - val_accuracy: 0.7637 - val_recall: 0.7188 - val_precision: 0.8044
# Epoch 84/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5516 - auc: 0.9457 - accuracy: 0.7747 - recall: 0.7310 - precision: 0.8064 - val_loss: 0.6067 - val_auc: 0.9427 - val_accuracy: 0.7637 - val_recall: 0.7197 - val_precision: 0.8063
# Epoch 85/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5614 - auc: 0.9437 - accuracy: 0.7674 - recall: 0.7271 - precision: 0.8006 - val_loss: 0.6046 - val_auc: 0.9428 - val_accuracy: 0.7676 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 86/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5546 - auc: 0.9450 - accuracy: 0.7681 - recall: 0.7293 - precision: 0.8017 - val_loss: 0.5984 - val_auc: 0.9430 - val_accuracy: 0.7627 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 87/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5482 - auc: 0.9464 - accuracy: 0.7750 - recall: 0.7361 - precision: 0.8066 - val_loss: 0.5938 - val_auc: 0.9430 - val_accuracy: 0.7656 - val_recall: 0.7148 - val_precision: 0.8035
# Epoch 88/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.5518 - auc: 0.9454 - accuracy: 0.7740 - recall: 0.7283 - precision: 0.8065 - val_loss: 0.6014 - val_auc: 0.9431 - val_accuracy: 0.7666 - val_recall: 0.7188 - val_precision: 0.8061
# Epoch 89/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5577 - auc: 0.9449 - accuracy: 0.7757 - recall: 0.7303 - precision: 0.8056 - val_loss: 0.5857 - val_auc: 0.9432 - val_accuracy: 0.7695 - val_recall: 0.7197 - val_precision: 0.8046
# Epoch 90/100
# 257/257 [==============================] - 17s 64ms/step - loss: 0.5402 - auc: 0.9480 - accuracy: 0.7769 - recall: 0.7359 - precision: 0.8111 - val_loss: 0.5966 - val_auc: 0.9429 - val_accuracy: 0.7646 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 91/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5411 - auc: 0.9478 - accuracy: 0.7747 - recall: 0.7342 - precision: 0.8095 - val_loss: 0.6034 - val_auc: 0.9430 - val_accuracy: 0.7686 - val_recall: 0.7168 - val_precision: 0.8013
# Epoch 92/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5406 - auc: 0.9482 - accuracy: 0.7811 - recall: 0.7391 - precision: 0.8127 - val_loss: 0.6250 - val_auc: 0.9430 - val_accuracy: 0.7656 - val_recall: 0.7168 - val_precision: 0.8022
# Epoch 93/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5437 - auc: 0.9475 - accuracy: 0.7786 - recall: 0.7366 - precision: 0.8085 - val_loss: 0.6083 - val_auc: 0.9430 - val_accuracy: 0.7637 - val_recall: 0.7168 - val_precision: 0.8039
# Epoch 94/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5532 - auc: 0.9454 - accuracy: 0.7745 - recall: 0.7337 - precision: 0.8111 - val_loss: 0.6282 - val_auc: 0.9428 - val_accuracy: 0.7637 - val_recall: 0.7168 - val_precision: 0.8031
# Epoch 95/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5508 - auc: 0.9460 - accuracy: 0.7735 - recall: 0.7291 - precision: 0.8080 - val_loss: 0.6548 - val_auc: 0.9429 - val_accuracy: 0.7666 - val_recall: 0.7178 - val_precision: 0.8059
# Epoch 96/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5439 - auc: 0.9474 - accuracy: 0.7789 - recall: 0.7420 - precision: 0.8157 - val_loss: 0.6224 - val_auc: 0.9429 - val_accuracy: 0.7646 - val_recall: 0.7188 - val_precision: 0.8053
# Epoch 97/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5563 - auc: 0.9447 - accuracy: 0.7679 - recall: 0.7315 - precision: 0.8037 - val_loss: 0.6246 - val_auc: 0.9430 - val_accuracy: 0.7676 - val_recall: 0.7178 - val_precision: 0.8033
# Epoch 98/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5513 - auc: 0.9457 - accuracy: 0.7662 - recall: 0.7249 - precision: 0.8001 - val_loss: 0.6243 - val_auc: 0.9432 - val_accuracy: 0.7676 - val_recall: 0.7197 - val_precision: 0.8037
# Epoch 99/100
# 257/257 [==============================] - 17s 66ms/step - loss: 0.5501 - auc: 0.9458 - accuracy: 0.7691 - recall: 0.7278 - precision: 0.8027 - val_loss: 0.5905 - val_auc: 0.9431 - val_accuracy: 0.7656 - val_recall: 0.7188 - val_precision: 0.8070
# Epoch 100/100
# 257/257 [==============================] - 17s 65ms/step - loss: 0.5470 - auc: 0.9468 - accuracy: 0.7740 - recall: 0.7313 - precision: 0.8028 - val_loss: 0.6100 - val_auc: 0.9429 - val_accuracy: 0.7646 - val_recall: 0.7188 - val_precision: 0.8061

# %% [markdown]
# # Visualize Model Metrics
#
# Let's graph the ROC AUC metric and loss after each epoch for the training and validation data. Although we didn't use a random seed for our notebook, the results may slightly vary, generally the scores for the validataion data is similar, if not better, than the training dataset.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['auc', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# # Evaluate the Model
#
# Although we used the validatation dataset to continually evaluate the model, we also have a separate testing dataset. Let's prepare the testing dataset.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/LeWagon/raw_data/AlzheimersDataset/test",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

test_ds = test_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 1279 files belonging to 4 classes.

# %%
_ = model.evaluate(test_ds)
# Out:
# 80/80 [==============================] - 201s 2s/step - loss: 1.1236 - auc: 0.8531 - accuracy: 0.6005 - recall: 0.5629 - precision: 0.6218

# %%
_
# Out:
# [1.1235615015029907,
#  0.8531404733657837,
#  0.6004691123962402,
#  0.5629398226737976,
#  0.621761679649353]
